# %%
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd
# %matplotlib inline

noise = np.random.rand(44100 * .5)
noise[noise>0.1] = 1
#sd.play(noise, 44100)

# %%
noise = np.random.rand(44100 * .5)
noise[noise<0.8] = .5
plt.plot(noise[:200], lw = 0.5)

sd.play(noise, 44100)
# Out:
# c:\python27\lib\site-packages\ipykernel\__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':

# %%
def band_limited_noise(min_freq, max_freq, samples=1024, samplerate=1):
    freqs = np.abs(np.fft.fftfreq(samples, float(1)/samplerate))
    f = np.zeros(samples)
    idx = np.where(np.logical_and(freqs>=min_freq, freqs<=max_freq))[0]
    f[idx] = 1
    return fftnoise(f)

def fftnoise(f):
    f = np.array(f, dtype='complex')
    Np = (len(f) - 1) // 2
    phases = np.random.rand(Np) * 2 * np.pi
    phases = np.cos(phases) + 1j * np.sin(phases)
    f[1:Np+1] *= phases
    f[-1:-1-Np:-1] = np.conj(f[1:Np+1])
    return np.fft.ifft(f).real

noise = band_limited_noise(5000, 20000, samples=int(44100*0.5), samplerate=44100)

noise = noise/ noise.min()

sd.play(noise*.5, 44100)

# %%
plt.plot(noise[:44100])
